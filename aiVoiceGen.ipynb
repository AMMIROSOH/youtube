# %%
from openai import OpenAI
client = OpenAI()

# %%
name = "this will take forever"
with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="nova",
    input=name
) as response:
    response.stream_to_file(f"voices/{name}.mp3")
